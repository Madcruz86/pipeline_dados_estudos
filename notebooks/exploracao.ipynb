# %% [markdown]
# # Lendo os dados

# %%
path_json = '../data_raw/dados_empresaA.json'

# %%
with open(path_json, 'r') as file:
    dados = (file.readline())

# %%
import json

# %%
with open(path_json, 'r') as file:
    dados_json = json.load(file)

# %%
dados_json[0:3]
# Out:
# [{'Nome do Produto': 'Blush em pó',
#   'Categoria do Produto': 'Eletrodomésticos',
#   'Preço do Produto (R$)': 79.41,
#   'Quantidade em Estoque': 7,
#   'Filial': 'Filial 7'},
#  {'Nome do Produto': 'Lápis de sobrancelha',
#   'Categoria do Produto': 'Eletrodomésticos',
#   'Preço do Produto (R$)': 85.47,
#   'Quantidade em Estoque': 78,
#   'Filial': 'Filial 8'},
#  {'Nome do Produto': 'Base líquida',
#   'Categoria do Produto': 'Roupas',
#   'Preço do Produto (R$)': 75.02,
#   'Quantidade em Estoque': 34,
#   'Filial': 'Filial 8'}]

# %%
path_csv = '../data_raw/dados_empresaB.csv'

# %%
with open(path_csv, 'r') as file:
    print(file.readlines()[1])
# Out:
# Lápis de sobrancelha,Roupas,55.17,62,Filial 1,2023-04-13 18:58:06.794203

# %%
with open(path_csv, 'r') as file:
    dados_csv = (file.readlines())

# %%
dados_csv[1][0]
# Out:
# 'L'

# %%
import csv

dados_csv = []

with open(path_csv, 'r') as file:
    spamreader = csv.reader(file, delimiter=',')
    print(type(spamreader))
    for item in spamreader:
        dados_csv.append(item)
# Out:
# <class '_csv.reader'>

# %%
dados_csv[0][0]
# Out:
# 'Nome do Item'

# %%
dados_json[0]['Quantidade em Estoque']
# Out:
# 7

# %%
dados_csv[1]
# Out:
# ['Lápis de sobrancelha',
#  'Roupas',
#  '55.17',
#  '62',
#  'Filial 1',
#  '2023-04-13 18:58:06.794203']

# %%
dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.DictReader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

# %%
dados_csv[1]
# Out:
# {'Nome do Item': 'Batom matte',
#  'Classificação do Produto': 'Eletrônicos',
#  'Valor em Reais (R$)': '74.15',
#  'Quantidade em Estoque': '48',
#  'Nome da Loja': 'Filial 9',
#  'Data da Venda': '2023-06-03 18:58:06.794203'}

# %%
nome_colunas_json = list(dados_json[0].keys())
nome_colunas_json
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
len(nome_colunas_json)
# Out:
# 5

# %%
nome_colunas_csv = list(dados_csv[0].keys())
nome_colunas_csv
# Out:
# ['Nome do Item',
#  'Classificação do Produto',
#  'Valor em Reais (R$)',
#  'Quantidade em Estoque',
#  'Nome da Loja',
#  'Data da Venda']

# %%
len(nome_colunas_csv)
# Out:
# 6

# %%
key_mapping = {'Nome do Item': 'Nome do Produto',
                'Classificação do Produto': 'Categorida do Produto',
                'Valor em Reais (R$)': 'Preco do Produto (R$)',
                'Quantidade em Estoque': 'Quantidade em Estoque',
                'Nome da Loja': 'Filial',
                'Data da Venda': 'Data da Venda'}

# %%
new_dados_csv = []

for old_dict in dados_csv:
    dict_temp = {}
    for old_key, value in old_dict.items():
        dict_temp[key_mapping[old_key]] = value
    new_dados_csv.append(dict_temp)

new_dados_csv[0]
# Out:
# {'Nome do Produto': 'Lápis de sobrancelha',
#  'Categorida do Produto': 'Roupas',
#  'Preco do Produto (R$)': '55.17',
#  'Quantidade em Estoque': '62',
#  'Filial': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
len(dados_json)
# Out:
# 3123

# %%
len(new_dados_csv)
# Out:
# 1323

# %%
combined_list = []
combined_list.extend(dados_json)
combined_list.extend(new_dados_csv)

# %%
len(combined_list)
# Out:
# 4446

# %%
combined_list[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
combined_list[-1]
# Out:
# {'Nome do Produto': 'Sombra de olhos',
#  'Categorida do Produto': 'Eletrônicos',
#  'Preco do Produto (R$)': '41.73',
#  'Quantidade em Estoque': '5',
#  'Filial': 'Filial 6',
#  'Data da Venda': '2022-11-21 18:58:06.794203'}

# %%
new_dados_csv[-1]
# Out:
# {'Nome do Produto': 'Sombra de olhos',
#  'Categorida do Produto': 'Eletrônicos',
#  'Preco do Produto (R$)': '41.73',
#  'Quantidade em Estoque': '5',
#  'Filial': 'Filial 6',
#  'Data da Venda': '2022-11-21 18:58:06.794203'}

# %%
nomes_colunas = list(combined_list[0].keys())
nomes_colunas
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
path_dados_combinados = '../data_processed/dados_combinados.csv'

with open(path_dados_combinados, 'w') as file:
    writer = csv.DictWriter(file, fieldnames=nomes_colunas)
    writer.writeheader()

    for row in combined_list:
        writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 8
#       4     writer = csv.DictWriter(file, fieldnames=nomes_colunas)
#       5     writer.writeheader()
#       6
#       7     for row in combined_list:
# ----> 8         writer.writerow(row)
#
# File /usr/lib/python3.14/csv.py:225, in DictWriter.writerow(self, rowdict)
#     224 def writerow(self, rowdict):
# --> 225     return self.writer.writerow(self._dict_to_list(rowdict))
#
# File /usr/lib/python3.14/csv.py:220, in DictWriter._dict_to_list(self, rowdict)
#     218     wrong_fields = rowdict.keys() - self.fieldnames
#     219     if wrong_fields:
# --> 220         raise ValueError("dict contains fields not in fieldnames: "
#     221                          + ", ".join([repr(x) for x in wrong_fields]))
#     222 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'Categorida do Produto', 'Data da Venda', 'Preco do Produto (R$)'
